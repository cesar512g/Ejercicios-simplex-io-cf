# %%
import numpy as np
from scipy.optimize import linprog

# Definir los coeficientes de la función objetivo
c = np.array([-4, -6])

# Definir las restricciones del problema
A = np.array([[2, -1], [1, 1]])
b = np.array([2, 4])

# Definir los límites de las variables
x0_bounds = (0, None)
x1_bounds = (0, None)

# Resolver el problema usando linprog()
res = linprog(c, A_ub=A, b_ub=b, bounds=[x0_bounds, x1_bounds])


print("La funcion linprog se va a encargar de automizar el proceso simplex mostrando los pasos y el valor optimo","\n")

# Mostrar el resultado
print(res)

# Mostrar el valor óptimo de la función objetivo
print("valor optimo de la solucion acotada = ",-1*res.fun-10)
# Out:
# La funcion linprog se va a encargar de automizar el proceso simplex mostrando los pasos y el valor optimo
#
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -24.0
#               x: [ 0.000e+00  4.000e+00]
#             nit: 0
#           lower:  residual: [ 0.000e+00  4.000e+00]
#                  marginals: [ 2.000e+00  0.000e+00]
#           upper:  residual: [       inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 6.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -6.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# valor optimo de la solucion acotada =  14.0
